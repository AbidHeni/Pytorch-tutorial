# %% [markdown]
# <a href="https://colab.research.google.com/github/AbidHeni/Pytorch-tutorial/blob/newB/myFirst_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello
